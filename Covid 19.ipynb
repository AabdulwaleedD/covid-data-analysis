# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\Administrator\Desktop\Datasets\covid19_patient_symptoms_diagnosis.csv")
df.head(20)
# Out:
#     patient_id  age  gender  fever  dry_cough  sore_throat  fatigue  headache  \
# 0            1   52    Male      1          0            1        1         0
# 1            2   15    Male      0          0            0        1         1
# 2            3   72    Male      1          0            1        0         0
# 3            4   61  Female      0          0            1        1         1
# 4            5   21  Female      1          1            0        0         0
# 5            6   83  Female      0          1            0        1         1
# 6            7   87    Male      1          1            0        1         0
# 7            8   75  Female      0          1            1        0         0
# 8            9   75  Female      1          0            1        0         0
# 9           10   88  Female      0          1            0        1         1
# 10          11   24    Male      1          1            0        1         0
# ...

# %%
df.columns = (
    df.columns.str.replace("[^0-9a-zA-Z_]+", "_", regex=True)
              .str.strip("_")
)
df.columns
# Out:
# Index(['patient_id', 'age', 'gender', 'fever', 'dry_cough', 'sore_throat',
#        'fatigue', 'headache', 'shortness_of_breath', 'loss_of_smell',
#        'loss_of_taste', 'oxygen_level', 'body_temperature', 'comorbidity',
#        'travel_history', 'contact_with_patient', 'chest_pain', 'covid_result'],
#       dtype='object')

# %%
df.describe()
# Out:
#         patient_id          age        fever    dry_cough  sore_throat  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean   2500.500000    44.380600     0.567400     0.493200     0.416000
# std    1443.520003    25.551632     0.495486     0.500004     0.492943
# min       1.000000     1.000000     0.000000     0.000000     0.000000
# 25%    1250.750000    22.000000     0.000000     0.000000     0.000000
# 50%    2500.500000    44.000000     1.000000     0.000000     0.000000
# 75%    3750.250000    66.000000     1.000000     1.000000     1.000000
# max    5000.000000    89.000000     1.000000     1.000000     1.000000
#
#            fatigue     headache  shortness_of_breath  loss_of_smell  \
# count  5000.000000  5000.000000          5000.000000    5000.000000
# mean      0.589800     0.444800             0.348400       0.299400
# std       0.491919     0.496993             0.476511       0.458041
# ...

# %%
df.isnull().sum()
# Out:
# patient_id                 0
# age                        0
# gender                     0
# fever                      0
# dry_cough                  0
# sore_throat                0
# fatigue                    0
# headache                   0
# shortness_of_breath        0
# loss_of_smell              0
# loss_of_taste              0
# oxygen_level               0
# body_temperature           0
# comorbidity             2725
# travel_history             0
# contact_with_patient       0
# chest_pain                 0
# covid_result               0
# dtype: int64

# %%
df.fillna = 0

# %%
df.isnull().sum()
# Out:
# patient_id                 0
# age                        0
# gender                     0
# fever                      0
# dry_cough                  0
# sore_throat                0
# fatigue                    0
# headache                   0
# shortness_of_breath        0
# loss_of_smell              0
# loss_of_taste              0
# oxygen_level               0
# body_temperature           0
# comorbidity             2725
# travel_history             0
# contact_with_patient       0
# chest_pain                 0
# covid_result               0
# dtype: int64

# %%
df.sort_values(by="age", ascending=False)
# Out:
#       patient_id  age  gender  fever  dry_cough  sore_throat  fatigue  \
# 4995        4996   89  Female      0          1            1        0
# 3939        3940   89  Female      0          1            0        0
# 1571        1572   89  Female      1          1            1        0
# 426          427   89    Male      0          1            1        1
# 1514        1515   89  Female      1          1            0        0
# ...          ...  ...     ...    ...        ...          ...      ...
# 3154        3155    1    Male      1          0            1        1
# 610          611    1    Male      1          0            0        0
# 4418        4419    1  Female      1          0            0        1
# 255          256    1  Female      0          0            0        0
# 243          244    1  Female      0          1            1        0
#
#       headache  shortness_of_breath  loss_of_smell  loss_of_taste  \
# ...

# %%
df1 = df.loc[df['covid_result'] >= 1]
df1
# Out:
#       patient_id  age  gender  fever  dry_cough  sore_throat  fatigue  \
# 4              5   21  Female      1          1            0        0
# 7              8   75  Female      0          1            1        0
# 10            11   24    Male      1          1            0        1
# 12            13   22    Male      1          1            1        1
# 14            15    2  Female      1          1            0        0
# ...          ...  ...     ...    ...        ...          ...      ...
# 4989        4990   18    Male      1          0            1        1
# 4991        4992   55    Male      0          1            1        0
# 4996        4997   62    Male      1          1            0        0
# 4997        4998   13  Female      0          1            1        1
# 4999        5000    6    Male      0          1            0        0
#
#       headache  shortness_of_breath  loss_of_smell  loss_of_taste  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2600 entries, 4 to 4999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   patient_id            2600 non-null   int64
#  1   age                   2600 non-null   int64
#  2   gender                2600 non-null   object
#  3   fever                 2600 non-null   int64
#  4   dry_cough             2600 non-null   int64
#  5   sore_throat           2600 non-null   int64
#  6   fatigue               2600 non-null   int64
#  7   headache              2600 non-null   int64
#  8   shortness_of_breath   2600 non-null   int64
#  9   loss_of_smell         2600 non-null   int64
#  10  loss_of_taste         2600 non-null   int64
#  11  oxygen_level          2600 non-null   int64
#  12  body_temperature      2600 non-null   float64
#  13  comorbidity           1157 non-null   object
#  14  travel_history        2600 non-null   int64
# ...

# %%
df2 = df.loc[df["body_temperature"] > 40]
df2
# Out:
#       patient_id  age  gender  fever  dry_cough  sore_throat  fatigue  \
# 8              9   75  Female      1          0            1        0
# 17            18   38    Male      0          1            0        1
# 28            29   59  Female      1          1            1        1
# 32            33   15    Male      0          0            0        0
# 34            35   62  Female      1          1            1        1
# ...          ...  ...     ...    ...        ...          ...      ...
# 4973        4974    9  Female      1          1            0        0
# 4974        4975   40  Female      1          0            1        0
# 4991        4992   55    Male      0          1            1        0
# 4997        4998   13  Female      0          1            1        1
# 4999        5000    6    Male      0          1            0        0
#
#       headache  shortness_of_breath  loss_of_smell  loss_of_taste  \
# ...
